# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.papers.grover import test_single_config

result = test_single_config("S3-1", "IDEAL", num_runs=5)
# Out:
# ============================================================
# Running S3-1 with IDEAL (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.9375
#   Run 2/5... Success rate: 0.9482
#   Run 3/5... Success rate: 0.9375
#   Run 4/5... Success rate: 0.9443
#   Run 5/5... Success rate: 0.9512
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.9437 ± 0.0062
#   Median: 0.9443
#   Range:  [0.9375, 0.9512]
#   95% CI: [0.9383, 0.9492]
#
# Distribution Shape:
#   Skewness: 0.013
#   Kurtosis: -1.626
#   Normal:   Yes (p=0.3439)

# %%
# Run pilot study
from qward.examples.papers.grover import test_pilot_study

results = test_pilot_study()
# Out:
# ######################################################################
# GROVER EXPERIMENT CAMPAIGN
# ######################################################################
# Configurations: 4
# Noise models: 2
# Runs per batch: 5
# Shots per run: 1024
# Total batches: 8
# ######################################################################
#
# [1/8]
# ============================================================
# Running S3-1 with IDEAL (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.9512
#   Run 2/5... Success rate: 0.9551
#   Run 3/5... Success rate: 0.9541
#   Run 4/5... Success rate: 0.9502
#   Run 5/5... Success rate: 0.9424
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.9506 ± 0.0050
#   Median: 0.9512
#   Range:  [0.9424, 0.9551]
#   95% CI: [0.9462, 0.9550]
#
# Distribution Shape:
#   Skewness: -0.930
#   Kurtosis: -0.472
#   Normal:   Yes (p=0.2964)
#
# [2/8]
# ============================================================
# Running S3-1 with DEP-MED (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.2637
#   Run 2/5... Success rate: 0.2754
#   Run 3/5... Success rate: 0.2725
#   Run 4/5... Success rate: 0.2803
#   Run 5/5... Success rate: 0.2666
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.2717 ± 0.0067
#   Median: 0.2725
#   Range:  [0.2637, 0.2803]
#   95% CI: [0.2658, 0.2775]
#
# Distribution Shape:
#   Skewness: 0.039
#   Kurtosis: -1.358
#   Normal:   Yes (p=0.8846)
#
# Noise Impact (vs IDEAL):
#   Degradation: 71.4%
#   Effect Size: Large (d=115.07)
#
# [3/8]
# ============================================================
# Running M3-1 with IDEAL (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.9365
#   Run 2/5... Success rate: 0.9492
#   Run 3/5... Success rate: 0.9336
#   Run 4/5... Success rate: 0.9453
#   Run 5/5... Success rate: 0.9492
#
# ============================================================
# STATISTICAL ANALYSIS: M3-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.9428 ± 0.0073
#   Median: 0.9453
#   Range:  [0.9336, 0.9492]
#   95% CI: [0.9364, 0.9492]
#
# Distribution Shape:
#   Skewness: -0.335
#   Kurtosis: -1.663
#   Normal:   Yes (p=0.1937)
#
# [4/8]
# ============================================================
# Running M3-1 with DEP-MED (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.3018
#   Run 2/5... Success rate: 0.2803
#   Run 3/5... Success rate: 0.2715
#   Run 4/5... Success rate: 0.2949
#   Run 5/5... Success rate: 0.2900
#
# ============================================================
# STATISTICAL ANALYSIS: M3-1 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.2877 ± 0.0120
#   Median: 0.2900
#   Range:  [0.2715, 0.3018]
#   95% CI: [0.2772, 0.2982]
#
# Distribution Shape:
#   Skewness: -0.244
#   Kurtosis: -1.267
#   Normal:   Yes (p=0.9126)
#
# Noise Impact (vs IDEAL):
#   Degradation: 69.5%
#   Effect Size: Large (d=66.08)
#
# [5/8]
# ============================================================
# Running H3-0 with IDEAL (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.9531
#   Run 2/5... Success rate: 0.9473
#   Run 3/5... Success rate: 0.9453
#   Run 4/5... Success rate: 0.9453
#   Run 5/5... Success rate: 0.9434
#
# ============================================================
# STATISTICAL ANALYSIS: H3-0 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.9469 ± 0.0038
#   Median: 0.9453
#   Range:  [0.9434, 0.9531]
#   95% CI: [0.9436, 0.9502]
#
# Distribution Shape:
#   Skewness: 1.018
#   Kurtosis: -0.348
#   Normal:   Yes (p=0.2230)
#
# [6/8]
# ============================================================
# Running H3-0 with DEP-MED (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.2969
#   Run 2/5... Success rate: 0.2764
#   Run 3/5... Success rate: 0.2734
#   Run 4/5... Success rate: 0.2930
#   Run 5/5... Success rate: 0.2881
#
# ============================================================
# STATISTICAL ANALYSIS: H3-0 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.2855 ± 0.0103
#   Median: 0.2881
#   Range:  [0.2734, 0.2969]
#   95% CI: [0.2766, 0.2945]
#
# Distribution Shape:
#   Skewness: -0.174
#   Kurtosis: -1.640
#   Normal:   Yes (p=0.4770)
#
# Noise Impact (vs IDEAL):
#   Degradation: 69.8%
#   Effect Size: Large (d=85.63)
#
# [7/8]
# ============================================================
# Running H3-3 with IDEAL (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.9580
#   Run 2/5... Success rate: 0.9492
#   Run 3/5... Success rate: 0.9443
#   Run 4/5... Success rate: 0.9541
#   Run 5/5... Success rate: 0.9414
#
# ============================================================
# STATISTICAL ANALYSIS: H3-3 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.9494 ± 0.0068
#   Median: 0.9492
#   Range:  [0.9414, 0.9580]
#   95% CI: [0.9434, 0.9554]
#
# Distribution Shape:
#   Skewness: 0.082
#   Kurtosis: -1.448
#   Normal:   Yes (p=0.8440)
#
# [8/8]
# ============================================================
# Running H3-3 with DEP-MED (5 runs)
# ============================================================
#   Run 1/5... Success rate: 0.2979
#   Run 2/5... Success rate: 0.2998
#   Run 3/5... Success rate: 0.3027
#   Run 4/5... Success rate: 0.2959
#   Run 5/5... Success rate: 0.3193
#
# ============================================================
# STATISTICAL ANALYSIS: H3-3 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=5):
#   Mean:   0.3031 ± 0.0094
#   Median: 0.2998
#   Range:  [0.2959, 0.3193]
#   95% CI: [0.2949, 0.3114]
#
# Distribution Shape:
#   Skewness: 1.242
#   Kurtosis: -0.100
#   Normal:   Yes (p=0.0711)
#
# Noise Impact (vs IDEAL):
#   Degradation: 68.1%
#   Effect Size: Large (d=78.68)
#
# ######################################################################
# CAMPAIGN COMPLETE
# ######################################################################

# %%
# Full campaign
from qward.examples.papers.grover import run_experiment_campaign

results = run_experiment_campaign(
    config_ids=["S3-1", "S4-1", "S5-1"],
    noise_ids=["IDEAL", "DEP-LOW", "DEP-MED"],
    num_runs=10,
    save_results=True,
)
# Out:
# ######################################################################
# GROVER EXPERIMENT CAMPAIGN
# ######################################################################
# Configurations: 3
# Noise models: 3
# Runs per batch: 10
# Shots per run: 1024
# Total batches: 9
# ######################################################################
#
# [1/9]
# ============================================================
# Running S3-1 with IDEAL (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.9434
#   Run 2/10... Success rate: 0.9414
#   Run 3/10... Success rate: 0.9355
#   Run 4/10... Success rate: 0.9512
#   Run 5/10... Success rate: 0.9551
#   Run 6/10... Success rate: 0.9463
#   Run 7/10... Success rate: 0.9463
#   Run 8/10... Success rate: 0.9551
#   Run 9/10... Success rate: 0.9473
#   Run 10/10... Success rate: 0.9443
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.9466 ± 0.0061
#   Median: 0.9463
#   Range:  [0.9355, 0.9551]
#   95% CI: [0.9428, 0.9503]
#
# Distribution Shape:
#   Skewness: -0.107
#   Kurtosis: -0.563
#   Normal:   Yes (p=0.7062)
#
# [2/9]
# ============================================================
# Running S3-1 with DEP-LOW (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.7500
#   Run 2/10... Success rate: 0.7607
#   Run 3/10... Success rate: 0.7451
#   Run 4/10... Success rate: 0.7754
#   Run 5/10... Success rate: 0.7568
#   Run 6/10... Success rate: 0.7441
#   Run 7/10... Success rate: 0.7422
#   Run 8/10... Success rate: 0.7520
#   Run 9/10... Success rate: 0.7422
#   Run 10/10... Success rate: 0.7441
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (DEP-LOW)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.7513 ± 0.0106
#   Median: 0.7476
#   Range:  [0.7422, 0.7754]
#   95% CI: [0.7447, 0.7578]
#
# Distribution Shape:
#   Skewness: 1.243
#   Kurtosis: 0.612
#   Normal:   Yes (p=0.0386)
#
# Noise Impact (vs IDEAL):
#   Degradation: 20.6%
#   Effect Size: Large (d=22.64)
#
# [3/9]
# ============================================================
# Running S3-1 with DEP-MED (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.2900
#   Run 2/10... Success rate: 0.2891
#   Run 3/10... Success rate: 0.2656
#   Run 4/10... Success rate: 0.3008
#   Run 5/10... Success rate: 0.2939
#   Run 6/10... Success rate: 0.2852
#   Run 7/10... Success rate: 0.3057
#   Run 8/10... Success rate: 0.2754
#   Run 9/10... Success rate: 0.2979
#   Run 10/10... Success rate: 0.2754
#
# ============================================================
# STATISTICAL ANALYSIS: S3-1 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.2879 ± 0.0126
#   Median: 0.2896
#   Range:  [0.2656, 0.3057]
#   95% CI: [0.2801, 0.2957]
#
# Distribution Shape:
#   Skewness: -0.347
#   Kurtosis: -0.910
#   Normal:   Yes (p=0.8319)
#
# Noise Impact (vs IDEAL):
#   Degradation: 69.6%
#   Effect Size: Large (d=66.43)
#
# [4/9]
# ============================================================
# Running S4-1 with IDEAL (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.9629
#   Run 2/10... Success rate: 0.9648
#   Run 3/10... Success rate: 0.9551
#   Run 4/10... Success rate: 0.9619
#   Run 5/10... Success rate: 0.9619
#   Run 6/10... Success rate: 0.9629
#   Run 7/10... Success rate: 0.9688
#   Run 8/10... Success rate: 0.9629
#   Run 9/10... Success rate: 0.9541
#   Run 10/10... Success rate: 0.9639
#
# ============================================================
# STATISTICAL ANALYSIS: S4-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.9619 ± 0.0043
#   Median: 0.9629
#   Range:  [0.9541, 0.9688]
#   95% CI: [0.9592, 0.9646]
#
# Distribution Shape:
#   Skewness: -0.631
#   Kurtosis: -0.160
#   Normal:   Yes (p=0.1010)
#
# [5/9]
# ============================================================
# Running S4-1 with DEP-LOW (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.4561
#   Run 2/10... Success rate: 0.4473
#   Run 3/10... Success rate: 0.4736
#   Run 4/10... Success rate: 0.4570
#   Run 5/10... Success rate: 0.4092
#   Run 6/10... Success rate: 0.4395
#   Run 7/10... Success rate: 0.4658
#   Run 8/10... Success rate: 0.4551
#   Run 9/10... Success rate: 0.4277
#   Run 10/10... Success rate: 0.4434
#
# ============================================================
# STATISTICAL ANALYSIS: S4-1 (DEP-LOW)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.4475 ± 0.0188
#   Median: 0.4512
#   Range:  [0.4092, 0.4736]
#   95% CI: [0.4358, 0.4591]
#
# Distribution Shape:
#   Skewness: -0.675
#   Kurtosis: -0.131
#   Normal:   Yes (p=0.7397)
#
# Noise Impact (vs IDEAL):
#   Degradation: 53.5%
#   Effect Size: Large (d=37.71)
#
# [6/9]
# ============================================================
# Running S4-1 with DEP-MED (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.0664
#   Run 2/10... Success rate: 0.0703
#   Run 3/10... Success rate: 0.0664
#   Run 4/10... Success rate: 0.0654
#   Run 5/10... Success rate: 0.0723
#   Run 6/10... Success rate: 0.0654
#   Run 7/10... Success rate: 0.0752
#   Run 8/10... Success rate: 0.0850
#   Run 9/10... Success rate: 0.0781
#   Run 10/10... Success rate: 0.0771
#
# ============================================================
# STATISTICAL ANALYSIS: S4-1 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.0722 ± 0.0066
#   Median: 0.0713
#   Range:  [0.0654, 0.0850]
#   95% CI: [0.0681, 0.0763]
#
# Distribution Shape:
#   Skewness: 0.589
#   Kurtosis: -0.737
#   Normal:   Yes (p=0.2280)
#
# Noise Impact (vs IDEAL):
#   Degradation: 92.5%
#   Effect Size: Large (d=159.02)
#
# [7/9]
# ============================================================
# Running S5-1 with IDEAL (10 runs)
# ============================================================
#   Run 1/10... Success rate: 1.0000
#   Run 2/10... Success rate: 0.9980
#   Run 3/10... Success rate: 0.9980
#   Run 4/10... Success rate: 1.0000
#   Run 5/10... Success rate: 0.9990
#   Run 6/10... Success rate: 0.9980
#   Run 7/10... Success rate: 0.9990
#   Run 8/10... Success rate: 0.9980
#   Run 9/10... Success rate: 0.9980
#   Run 10/10... Success rate: 0.9971
#
# ============================================================
# STATISTICAL ANALYSIS: S5-1 (IDEAL)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.9985 ± 0.0009
#   Median: 0.9980
#   Range:  [0.9971, 1.0000]
#   95% CI: [0.9979, 0.9991]
#
# Distribution Shape:
#   Skewness: 0.383
#   Kurtosis: -0.837
#   Normal:   Yes (p=0.0947)
#
# [8/9]
# ============================================================
# Running S5-1 with DEP-LOW (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.0781
#   Run 2/10... Success rate: 0.0986
#   Run 3/10... Success rate: 0.0889
#   Run 4/10... Success rate: 0.0957
#   Run 5/10... Success rate: 0.0869
#   Run 6/10... Success rate: 0.1055
#   Run 7/10... Success rate: 0.0957
#   Run 8/10... Success rate: 0.0869
#   Run 9/10... Success rate: 0.0947
#   Run 10/10... Success rate: 0.0986
#
# ============================================================
# STATISTICAL ANALYSIS: S5-1 (DEP-LOW)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.0930 ± 0.0078
#   Median: 0.0952
#   Range:  [0.0781, 0.1055]
#   95% CI: [0.0881, 0.0978]
#
# Distribution Shape:
#   Skewness: -0.349
#   Kurtosis: -0.408
#   Normal:   Yes (p=0.7638)
#
# Noise Impact (vs IDEAL):
#   Degradation: 90.7%
#   Effect Size: Large (d=162.78)
#
# [9/9]
# ============================================================
# Running S5-1 with DEP-MED (10 runs)
# ============================================================
#   Run 1/10... Success rate: 0.0273
#   Run 2/10... Success rate: 0.0264
#   Run 3/10... Success rate: 0.0361
#   Run 4/10... Success rate: 0.0332
#   Run 5/10... Success rate: 0.0352
#   Run 6/10... Success rate: 0.0352
#   Run 7/10... Success rate: 0.0400
#   Run 8/10... Success rate: 0.0381
#   Run 9/10... Success rate: 0.0244
#   Run 10/10... Success rate: 0.0332
#
# ============================================================
# STATISTICAL ANALYSIS: S5-1 (DEP-MED)
# ============================================================
#
# Descriptive Statistics (n=10):
#   Mean:   0.0329 ± 0.0052
#   Median: 0.0342
#   Range:  [0.0244, 0.0400]
#   95% CI: [0.0297, 0.0361]
#
# Distribution Shape:
#   Skewness: -0.421
#   Kurtosis: -1.078
#   Normal:   Yes (p=0.3904)
#
# Noise Impact (vs IDEAL):
#   Degradation: 96.7%
#   Effect Size: Large (d=257.90)
#
# Results saved to /home/jovyan/work/qward/examples/papers/grover/data/simulator
#   Raw: /home/jovyan/work/qward/examples/papers/grover/data/simulator/raw
#   Aggregated: /home/jovyan/work/qward/examples/papers/grover/data/simulator/aggregated
#
# ######################################################################
# CAMPAIGN COMPLETE
# ######################################################################

# %%
# List all configurations
from qward.examples.papers.grover import list_all_configs, list_noise_configs

list_all_configs()
list_noise_configs()
# Out:
# ================================================================================
# GROVER EXPERIMENT CONFIGURATIONS
# ================================================================================
#
# SCALABILITY (7 configs)
# ----------------------------------------
#   S2-1: 2q, 1 marked, P(success)=1.000
#   S3-1: 3q, 1 marked, P(success)=0.945
#   S4-1: 4q, 1 marked, P(success)=0.961
#   S5-1: 5q, 1 marked, P(success)=0.999
#   S6-1: 6q, 1 marked, P(success)=0.997
#   S7-1: 7q, 1 marked, P(success)=0.996
#   S8-1: 8q, 1 marked, P(success)=1.000
#
# MARKED_COUNT (6 configs)
# ----------------------------------------
#   M3-1: 3q, 1 marked, P(success)=0.945
#   M3-2: 3q, 2 marked, P(success)=1.000
#   M3-4: 3q, 4 marked, P(success)=0.500
#   M4-1: 4q, 1 marked, P(success)=0.961
#   M4-2: 4q, 2 marked, P(success)=0.945
#   M4-4: 4q, 4 marked, P(success)=1.000
#
# HAMMING (7 configs)
# ----------------------------------------
#   H3-0: 3q, 1 marked, P(success)=0.945
#   H3-1: 3q, 1 marked, P(success)=0.945
#   H3-2: 3q, 1 marked, P(success)=0.945
#   H3-3: 3q, 1 marked, P(success)=0.945
#   H4-0: 4q, 1 marked, P(success)=0.961
#   H4-2: 4q, 1 marked, P(success)=0.961
#   H4-4: 4q, 1 marked, P(success)=0.961
#
# SYMMETRY (4 configs)
# ----------------------------------------
#   SYM-1: 3q, 2 marked, P(success)=1.000
#   SYM-2: 3q, 2 marked, P(success)=1.000
#   ASYM-1: 3q, 2 marked, P(success)=1.000
#   ASYM-2: 3q, 2 marked, P(success)=1.000
#
# ================================================================================
# TOTAL: 24 experiment configurations
# NOISE MODELS: 8
# ================================================================================
# ============================================================
# NOISE MODEL CONFIGURATIONS
# ============================================================
#
# IDEAL: Perfect execution baseline
#
# DEP-LOW: Light depolarizing noise
#   Parameters: {'p1': 0.001, 'p2': 0.01}
#
# DEP-MED: Medium depolarizing noise
#   Parameters: {'p1': 0.01, 'p2': 0.05}
#
# DEP-HIGH: Heavy depolarizing noise
#   Parameters: {'p1': 0.05, 'p2': 0.1}
#
# PAULI: Structured Pauli errors
#   Parameters: {'pX': 0.01, 'pY': 0.01, 'pZ': 0.01}
#
# THERMAL: T1/T2 relaxation
#   Parameters: {'T1': 5e-05, 'T2': 7e-05}
#
# READOUT: Measurement errors only
#   Parameters: {'p01': 0.02, 'p10': 0.02}
#
# COMBINED: Realistic combined noise (DEP-MED + READOUT)
#   Parameters: {'p1': 0.01, 'p2': 0.05, 'p_readout': 0.02}
