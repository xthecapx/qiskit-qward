# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.visualization_demo import demo_circuit_performance_visualization

demo_circuit_performance_visualization()
# Out:
# QWARD CircuitPerformanceVisualizer Visualization Demo
# ========================================
# Circuit:         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
#    c: 2/══════════════╬══╬═
#                       ║  ║
# meas: 2/══════════════╩══╩═
#                       0  1
#
# Calculating CircuitPerformanceMetrics metrics...
#
# CircuitPerformanceMetrics metrics calculated successfully!
# Individual jobs: 3 jobs
# Aggregate data: (1, 28)
#
# ========================================
# Demo 1: Default Visualization (Direct Strategy)
# ========================================
# Creating CircuitPerformance visualizations...
# ✅ All CircuitPerformance plots saved to 'qward/examples/img/demo_plots_default/' directory.
# ✅ Created 4 plots with default settings
#
# ========================================
# Demo 2: Custom Configuration (Direct Strategy)
# ========================================
# Creating CircuitPerformance visualizations...
# ✅ All CircuitPerformance plots saved to 'qward/examples/img/demo_plots_custom/' directory.
# ✅ Created 4 plots with custom configuration
#
# ========================================
# Demo 3: Individual Plot Methods (Direct Strategy)
# ========================================
# Creating success vs error comparison...
# Creating fidelity comparison...
# Creating shot distribution...
# Creating aggregate summary...
# ✅ Created 4 individual plots
#
# ========================================
# Demo 4: Dashboard View (Direct Strategy)
# ========================================
# ✅ Created comprehensive dashboard
#
# ========================================
# Demo 5: Using Unified Visualizer (Recommended)
# ========================================
# Available metrics: ['CircuitPerformance']
# Creating dashboard for metrics: CircuitPerformance
# ✅ Created 1 unified dashboards
# Creating visualizations for metrics: CircuitPerformance
# Creating CircuitPerformance visualizations...
# ✅ All CircuitPerformance plots saved to 'qward/examples/img/demo_plots_unified/' directory.
# ✅ Created visualizations for 1 metric types
#
# ========================================
# Demo Complete!
# ========================================
# Check the following directories for generated plots:
# - qward/examples/img/demo_plots_default/
# - qward/examples/img/demo_plots_custom/
# - qward/examples/img/demo_plots_individual/
# - qward/examples/img/demo_plots_dashboard/
# - qward/examples/img/demo_plots_unified/
#
# Recommended approach: Use the unified Visualizer class (Demo 5)
# Direct strategy usage (Demos 1-4) is useful for advanced customization.

# %%
from qward.examples.example_visualizer import (
    example_basic_visualizer,
    example_with_circuit_performance,
    example_custom_config,
    example_custom_data,
    example_individual_strategies,
    example_custom_strategy,
    example_metric_summary,
)

example_basic_visualizer()
example_with_circuit_performance()
example_custom_config()
example_custom_data()
example_individual_strategies()
example_custom_strategy()
example_metric_summary()
# Out:
# === Example: Basic Visualizer Usage ===
# === QWARD Visualizer Summary ===
# Output directory: qward/examples/img
# Total metrics datasets: 2
# Available visualizations: 2
#   - QiskitMetrics: 1 dataset(s), 1 total rows
#   - ComplexityMetrics: 1 dataset(s), 1 total rows
#
# Creating dashboard...
# Creating dashboard for metrics: QiskitMetrics, ComplexityMetrics
# Created 2 dashboards:
#   - QiskitMetrics: Figure(1500x1200)
#   - ComplexityMetrics: Figure(1400x1000)
#
# === Example: All Visualizers with CircuitPerformanceVisualizer ===
# === QWARD Visualizer Summary ===
# Output directory: qward/examples/img
# Total metrics datasets: 4
# Available visualizations: 3
#   - CircuitPerformance: 2 dataset(s), 4 total rows
#   - QiskitMetrics: 1 dataset(s), 1 total rows
#   - ComplexityMetrics: 1 dataset(s), 1 total rows
#
# Creating comprehensive dashboard...
# Creating dashboard for metrics: CircuitPerformance, QiskitMetrics, ComplexityMetrics
# Created 3 dashboards:
#   - CircuitPerformance: Figure(1500x1200)
#   - QiskitMetrics: Figure(1500x1200)
#   - ComplexityMetrics: Figure(1400x1000)
#
# === Example: Custom Plot Configuration ===
# Creating QiskitMetrics visualizations with custom config...
# Creating QiskitMetrics visualizations...
# ✅ All QiskitMetrics plots saved to 'qward/examples/custom_plots/' directory.
# Created 4 QiskitMetrics plots
#
# === Example: Custom Metrics Data ===
# === QWARD Visualizer Summary ===
# Output directory: qward/examples/img
# Total metrics datasets: 1
# Available visualizations: 1
#   - QiskitMetrics: 1 dataset(s), 1 total rows
# Creating visualizations from custom data...
# Creating visualizations for metrics: QiskitMetrics
# Creating QiskitMetrics visualizations...
# ✅ All QiskitMetrics plots saved to 'qward/examples/img/' directory.
# Created visualizations for 1 metric types
#
# === Example: Individual Visualization Strategies ===
# Creating QiskitMetrics visualizations using QiskitVisualizer strategy...
# Creating QiskitMetrics visualizations...
# ✅ All QiskitMetrics plots saved to 'qward/examples/img/' directory.
# Created 4 QiskitMetrics plots
# Creating ComplexityMetrics visualizations using ComplexityVisualizer strategy...
# Creating ComplexityMetrics visualizations...
# ✅ All ComplexityMetrics plots saved to 'qward/examples/img/' directory.
# Created 3 ComplexityMetrics plots
# Creating CircuitPerformance visualizations using CircuitPerformanceVisualizer strategy...
# Creating CircuitPerformance visualizations...
# /home/jovyan/work/qward/visualization/base.py:306: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=self.config.figsize)
# ✅ All CircuitPerformance plots saved to 'qward/examples/img/' directory.
# Created 4 CircuitPerformance plots
#
# === Example: Custom Visualization Strategy ===
# Registered custom strategy!
# Available strategies: ['CustomMetrics']
# Creating visualizations with custom strategy...
# Created 1 custom plots
#
# === Example: Metric Summary ===
# Metrics Summary:
#
# QiskitMetrics:
#   Shape: (1, 25)
#   Has Data: True
#   Columns: 25 total
#   Sample values:
#     basic_metrics.depth: 3
#     basic_metrics.width: 4
#     basic_metrics.size: 4
#
# ComplexityMetrics:
#   Shape: (1, 19)
#   Has Data: True
#   Columns: 19 total
#   Sample values:
#     gate_based_metrics.gate_count: 4.0
#     gate_based_metrics.circuit_depth: 3.0
#     gate_based_metrics.t_count: 0.0
