# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.visualization_example import main

main()
# Out:
# 🎨 QWARD Visualization Examples
# ...
# === Example 1: Unified Visualizer ===
#
# === QWARD Visualizer Summary ===
# Output directory: qward/examples/img
# Total metrics datasets: 2
# Available visualizations: 2
#   - QiskitMetrics: 1 dataset(s), 1 total rows, 4 plots
#   - ComplexityMetrics: 1 dataset(s), 1 total rows, 3 plots
#
# Generating single plot...
#   ✓ Circuit structure plot saved
#
# Generating selected plots...
#   ✓ QiskitMetrics: 2 plots
#   ✓ ComplexityMetrics: 1 plots
#
# Creating dashboards...
# Creating dashboard for metrics: QiskitMetrics, ComplexityMetrics
#   ✓ Created 2 dashboards
#
# === Example 2: With CircuitPerformance ===
#
# === QWARD Visualizer Summary ===
# Output directory: qward/examples/img
# Total metrics datasets: 4
# Available visualizations: 3
#   - CircuitPerformance: 2 dataset(s), 4 total rows, 3 plots
#   - QiskitMetrics: 1 dataset(s), 1 total rows, 4 plots
#   - ComplexityMetrics: 1 dataset(s), 1 total rows, 3 plots
# ...
