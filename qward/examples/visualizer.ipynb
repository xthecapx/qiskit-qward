# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.visualization_demo import demo_success_rate_visualization

demo_success_rate_visualization()
# Out:
# QWARD SuccessRate Visualization Demo
# ...
# Circuit:         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
#    c: 2/══════════════╬══╬═
#                       ║  ║
# meas: 2/══════════════╩══╩═
#                       0  1
#
# Calculating SuccessRate metrics...
#
# SuccessRate metrics calculated successfully!
# Individual jobs: 3 jobs
# Aggregate data: (1, 7)
#
# ...
# Demo 1: Default Visualization
# ...
# Creating SuccessRate visualizations...
# ✅ All SuccessRate plots saved to 'img/demo_plots_default/' directory
# ✅ Created 4 plots with default settings
#
# ...
# Demo 2: Custom Configuration
# ...
# Creating SuccessRate visualizations...
# ✅ All SuccessRate plots saved to 'img/demo_plots_custom/' directory
# ✅ Created 4 plots with custom configuration
#
# ...
# Demo 3: Individual Plot Methods
# ...
# Creating success vs error comparison...
# Creating fidelity comparison...
# Creating shot distribution...
# ...
