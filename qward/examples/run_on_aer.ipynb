# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from qward.examples.aer import main

main()
# Out:
# Example 1: Using default metric calculators
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from qward.examples.aer import main
# ----> 3 main()
#
# File ~/work/qward/examples/aer.py:381, in main()
#     378 circuit = create_example_circuit()
#     380 # Run the examples with new naming
# --> 381 example_default_calculators(circuit)
#     382 example_qiskit_calculator(circuit)
#     383 example_backward_compatibility(circuit)
#
# File ~/work/qward/examples/aer.py:28, in example_default_calculators(circuit)
#      25 print("\nExample 1: Using default metric calculators")
#      27 # Create a scanner with the circuit
# ---> 28 scanner = Scanner(circuit=circuit)
#      30 # Add default calculators
#      31 scanner.add_calculator(QiskitMetrics(circuit))
#
# ...

# %%
from qward.examples.example_metrics_constructor import main

main()
# Out:
# Example: Calculators via Scanner constructor (calculator classes)
# QiskitMetrics DataFrame:
#    basic_metrics.depth  basic_metrics.width  basic_metrics.size  \
# 0                    3                    4                   4
#
#    basic_metrics.num_qubits  basic_metrics.num_clbits  \
# 0                         2                         2
#
#    basic_metrics.num_ancillas  basic_metrics.num_parameters  \
# 0                           0                             0
#
#    basic_metrics.has_calibrations  basic_metrics.has_layout  \
# 0                           False                     False
#
#    instruction_metrics.num_connected_components  \
# 0                                             1
#
#    instruction_metrics.num_nonlocal_gates  \
# 0                                       1
#
#    instruction_metrics.num_tensor_factors  \
# 0                                       1
#
#    instruction_metrics.num_unitary_factors  scheduling_metrics.is_scheduled  \
# ...
