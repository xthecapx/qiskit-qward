# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.aer import main

main()
# Out:
# QWARD Aer Examples
# ...
# Quantum Circuit:
# Example 1: Using default strategies
#
# QiskitMetrics DataFrame:
#    basic_metrics.depth  basic_metrics.width  basic_metrics.size  \
# 0                    3                    4                   4
#
#    basic_metrics.num_qubits  basic_metrics.num_clbits  \
# 0                         2                         2
#
#    basic_metrics.num_ancillas  basic_metrics.num_parameters  \
# 0                           0                             0
#
#    basic_metrics.has_calibrations  basic_metrics.has_layout  \
# 0                           False                     False
#
#    basic_metrics.count_ops.measure  ...  \
# 0                                2  ...
#
#    instruction_metrics.num_unitary_factors  \
# 0                                        1
#
#             instruction_metrics.instructions.measure  \
# 0  [(Instruction(name='measure', num_qubits=1, nu...
#
#                   instruction_metrics.instructions.h  \
# ...

# %%
from qward.examples.example_metrics_constructor import main

main()
# Out:
# Example: Strategies via Scanner constructor (strategy classes)
# QiskitMetrics DataFrame:
#    basic_metrics.depth  basic_metrics.width  basic_metrics.size  \
# 0                    3                    4                   4
#
#    basic_metrics.num_qubits  basic_metrics.num_clbits  \
# 0                         2                         2
#
#    basic_metrics.num_ancillas  basic_metrics.num_parameters  \
# 0                           0                             0
#
#    basic_metrics.has_calibrations  basic_metrics.has_layout  \
# 0                           False                     False
#
#    basic_metrics.count_ops.measure  ...  \
# 0                                2  ...
#
#    instruction_metrics.num_unitary_factors  \
# 0                                        1
#
#             instruction_metrics.instructions.measure  \
# 0  [(Instruction(name='measure', num_qubits=1, nu...
#
#                   instruction_metrics.instructions.h  \
# ...
