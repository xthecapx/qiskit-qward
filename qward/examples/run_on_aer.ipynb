# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.quickstart import main

main()
# Out:
# 🚀 QWARD Quickstart Examples
# ...
# === Example 0: Fluent API ===
#
# Metrics calculated: ['QiskitMetrics', 'ComplexityMetrics', 'ElementMetrics', 'StructuralMetrics', 'BehavioralMetrics', 'QuantumSpecificMetrics']
#
# ...
# 🎯 QWARD ANALYSIS SUMMARY
# ...
#
# 📈 Additional Metrics:
#    QiskitMetrics: 27 metrics calculated
#      Preview (first 5):
#        basic_metrics.depth: 3
#        basic_metrics.width: 6
#        basic_metrics.size: 4
#        basic_metrics.num_qubits: 2
#        basic_metrics.num_clbits: 4
#        ... and 22 more metrics
#    ComplexityMetrics: 19 metrics calculated
#      Preview (first 5):
#        gate_based_metrics.gate_count: 4.0
#        gate_based_metrics.circuit_depth: 3.0
#        gate_based_metrics.t_count: 0.0
#        gate_based_metrics.cnot_count: 1.0
#        gate_based_metrics.two_qubit_count: 1.0
#        ... and 14 more metrics
#    ElementMetrics: 31 metrics calculated
#      Preview (first 5):
#        no_p_x: 0.0
#        no_p_y: 0.0
#        no_p_z: 0.0
# ...
