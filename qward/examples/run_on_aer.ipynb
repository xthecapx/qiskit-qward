# %%
# %load_ext autoreload
# %autoreload 2

# %%
from qward.examples.aer import main

main()
# Out:
# Circuit:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
#
# Example 1: Using default metrics
#
# QiskitMetrics DataFrame:
#    basic_metrics.depth  basic_metrics.width  basic_metrics.size  \
# 0                    3                    4                   4
#
#            basic_metrics.count_ops  basic_metrics.num_qubits  \
# 0  {'measure': 2, 'h': 1, 'cx': 1}                         2
#
#    basic_metrics.num_clbits  basic_metrics.num_ancillas  \
# 0                         2                           0
#
#    basic_metrics.num_parameters  basic_metrics.has_calibrations  \
# 0                             0                           False
#
#    basic_metrics.has_layout  \
# 0                     False
#
#                     instruction_metrics.instructions  \
# 0  {'measure': [(Instruction(name='measure', num_...
#
#    instruction_metrics.num_connected_components  \
# ...
